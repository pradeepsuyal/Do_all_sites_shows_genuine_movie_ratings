# %% [markdown]
# ### The Data
#
# This is the data behind the story [Be Suspicious Of Online Movie Ratings, Especially Fandango’s](http://fivethirtyeight.com/features/fandango-movies-ratings/) openly available on 538's github: https://github.com/fivethirtyeight/data. There are two csv files, one with Fandango Stars and Displayed Ratings, and the other with aggregate data for movie ratings from other sites, like Metacritic,IMDB, and Rotten Tomatoes.
#
# #### all_sites_scores.csv

# %% [markdown]
# -----
#
# `all_sites_scores.csv` contains every film that has a Rotten Tomatoes rating, a RT User rating, a Metacritic score, a Metacritic User score, and IMDb score, and at least 30 fan reviews on Fandango. The data from Fandango was pulled on Aug. 24, 2015.

# %% [markdown]
# Column | Definition
# --- | -----------
# FILM | The film in question
# RottenTomatoes | The Rotten Tomatoes Tomatometer score  for the film
# RottenTomatoes_User | The Rotten Tomatoes user score for the film
# Metacritic | The Metacritic critic score for the film
# Metacritic_User | The Metacritic user score for the film
# IMDB | The IMDb user score for the film
# Metacritic_user_vote_count | The number of user votes the film had on Metacritic
# IMDB_user_vote_count | The number of user votes the film had on IMDb

# %% [markdown]
# ----
# ----
#
# #### fandango_scape.csv

# %% [markdown]
# `fandango_scrape.csv` contains every film 538 pulled from Fandango.
#
# Column | Definiton
# --- | ---------
# FILM | The movie
# STARS | Number of stars presented on Fandango.com
# RATING |  The Fandango ratingValue for the film, as pulled from the HTML of each page. This is the actual average score the movie obtained.
# VOTES | number of people who had reviewed the film at the time we pulled it.

# %% [markdown]
# ----
#
# **Importing essential libraries:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Let's first explore the Fandango ratings to see if our analysis agrees with the article's conclusion.

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %% [markdown]
# **Exploring the DataFrame Properties and Head.**

# %%
fandango.style.background_gradient(cmap='Paired')
# Out:
# <style  type="text/css" >
# ...

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe().style.background_gradient(cmap='Set2')
# Out:
# <style  type="text/css" >
# #T_2dda9_row0_col0,#T_2dda9_row0_col1,#T_2dda9_row7_col2{
#             background-color:  #b3b3b3;
#             color:  #000000;
#         }#T_2dda9_row0_col2,#T_2dda9_row1_col0,#T_2dda9_row1_col1,#T_2dda9_row1_col2,#T_2dda9_row2_col0,#T_2dda9_row2_col1,#T_2dda9_row2_col2,#T_2dda9_row3_col0,#T_2dda9_row3_col1,#T_2dda9_row3_col2,#T_2dda9_row4_col0,#T_2dda9_row4_col1,#T_2dda9_row4_col2,#T_2dda9_row5_col0,#T_2dda9_row5_col1,#T_2dda9_row5_col2,#T_2dda9_row6_col0,#T_2dda9_row6_col1,#T_2dda9_row6_col2,#T_2dda9_row7_col0,#T_2dda9_row7_col1{
#             background-color:  #66c2a5;
#             color:  #000000;
#         }</style><table id="T_2dda9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >STARS</th>        <th class="col_heading level0 col1" >RATING</th>        <th class="col_heading level0 col2" >VOTES</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# **exploring the relationship between popularity of a film and its rating. Creating a scatterplot showing the relationship between rating and votes.**

# %%
# setting up the chart size and background
plt.rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')

# for Interactive Shells
from IPython.display import display

# %%
sns.scatterplot(data=fandango,x='RATING',y='VOTES');

# %%
sns.scatterplot(data=fandango,x='STARS',y='VOTES');

# %% [markdown]
# **Calculating the correlation between the columns:**

# %%
fandango.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %% [markdown]
# **Assuming that every row in the FILM title column has the same format:**
#
#     Film Title Name (Year)
#
# **Now I will create a new column that is able to strip the year from the title strings and setting this new column as YEAR**

# %%
fandango['YEAR'] = fandango['FILM'].apply(lambda title:title.split('(')[-1])

# %% [markdown]
# **checking How many movies are in the Fandango DataFrame per year?**

# %%
fandango['YEAR'].value_counts()
# Out:
# 2015)    478
# 2014)     23
# 2012)      1
# 2016)      1
# 1964)      1
# Name: YEAR, dtype: int64

# %% [markdown]
# **Visualizing the count of movies per year:**

# %%
sns.countplot(data=fandango,x='YEAR')
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='count'>

# %% [markdown]
# **Let's see What are the 10 movies with the highest number of votes?**

# %%
fandango.nlargest(10,'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#     YEAR
# 0  2015)
# 1  2015)
# 2  2015)
# 3  2015)
# 4  2015)
# 5  2014)
# 6  2015)
# 7  2015)
# 8  2015)
# 9  2014)

# %% [markdown]
# **checking How many movies have zero votes?**

# %%
no_votes = fandango['VOTES']==0 
no_votes.sum()
# Out:
# 69

# %% [markdown]
# **Now I will Create DataFrame of only reviewed films by removing any films that have zero votes.**

# %%
fan_reviewed = fandango[fandango['VOTES']>0]

# %% [markdown]
# ----
#
# **As noted in the article, due to HTML and star rating displays, the true user rating may be slightly different than the rating shown to a user. Let's visualize this difference in distributions.**
#
# **Creating a KDE plot that displays the distribution of ratings that are displayed (STARS) versus what the true rating was from votes (RATING) and Clipping the KDEs to 0-5.**

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.kdeplot(data=fan_reviewed,x='RATING',clip=[0,5],fill=True,label='True Rating')
sns.kdeplot(data=fan_reviewed,x='STARS',clip=[0,5],fill=True,label='Stars Displayed')

plt.legend(loc=(1.05,0.5))

# %% [markdown]
# **Let's now actually quantify this discrepancy. Creating a new column of the difference between STARS displayed versus true RATING and Calculating this difference with STARS-RATING and rounding these differences to the nearest decimal point.**

# %%
import warnings
warnings.filterwarnings('ignore')


fan_reviewed["STARS_DIFF"] = fan_reviewed['STARS'] - fan_reviewed['RATING'] 
fan_reviewed['STARS_DIFF'] = fan_reviewed['STARS_DIFF'].round(2)

# %%
fan_reviewed
# Out:
#                             FILM  STARS  RATING  VOTES   YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015)         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015)         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015)         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015)         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015)         0.0
# ..                           ...    ...     ...    ...    ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015)         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015)         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015)         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015)         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015)         0.0
#
# [435 rows x 6 columns]

# %% [markdown]
# **Creating a count plot to display the number of times a certain difference occurs:**

# %%
sns.countplot(data=fan_reviewed,x='STARS_DIFF')
# Out:
# <AxesSubplot:xlabel='STARS_DIFF', ylabel='count'>

# %% [markdown]
# **We can see from the plot that one movie was displaying over a 1 star difference than its true rating! What movie had this close to 1 star differential?**

# %%
fan_reviewed[fan_reviewed['STARS_DIFF'] == 1]
# Out:
#                  FILM  STARS  RATING  VOTES   YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015)         1.0

# %% [markdown]
# ### Comparing of Fandango Ratings to Other Sites
#
# **Reading the "all_sites_scores.csv" file**

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %% [markdown]
# **Exploring the DataFrame columns, info, description.**

# %%
all_sites.head().style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
# #T_88f3d_row0_col1{
#             background-color:  #98d83e;
#             color:  #000000;
#         }#T_88f3d_row0_col2{
#             background-color:  #d5e21a;
#             color:  #000000;
#         }#T_88f3d_row0_col3{
#             background-color:  #f1e51d;
#             color:  #000000;
#         }#T_88f3d_row0_col4{
#             background-color:  #73d056;
#             color:  #000000;
#         }#T_88f3d_row0_col5,#T_88f3d_row0_col6,#T_88f3d_row0_col7,#T_88f3d_row1_col1,#T_88f3d_row1_col3,#T_88f3d_row2_col2,#T_88f3d_row2_col4,#T_88f3d_row2_col5{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_88f3d_row1_col2{
#             background-color:  #93d741;
#             color:  #000000;
#         }#T_88f3d_row1_col4{
#             background-color:  #aadc32;
#             color:  #000000;
#         }#T_88f3d_row1_col5{
#             background-color:  #58c765;
#             color:  #000000;
# ...

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe().style.background_gradient(cmap='Paired')
# Out:
# <style  type="text/css" >
# #T_e8ee8_row0_col0,#T_e8ee8_row0_col1,#T_e8ee8_row0_col2,#T_e8ee8_row0_col3,#T_e8ee8_row0_col4,#T_e8ee8_row7_col5,#T_e8ee8_row7_col6{
#             background-color:  #b15928;
#             color:  #f1f1f1;
#         }#T_e8ee8_row0_col5,#T_e8ee8_row0_col6,#T_e8ee8_row1_col3,#T_e8ee8_row1_col4,#T_e8ee8_row1_col5,#T_e8ee8_row2_col1,#T_e8ee8_row2_col2,#T_e8ee8_row2_col3,#T_e8ee8_row2_col4,#T_e8ee8_row3_col0,#T_e8ee8_row3_col1,#T_e8ee8_row3_col2,#T_e8ee8_row3_col3,#T_e8ee8_row3_col4,#T_e8ee8_row3_col5,#T_e8ee8_row3_col6,#T_e8ee8_row4_col3,#T_e8ee8_row4_col4,#T_e8ee8_row4_col5,#T_e8ee8_row4_col6,#T_e8ee8_row5_col3,#T_e8ee8_row5_col4,#T_e8ee8_row5_col5,#T_e8ee8_row5_col6,#T_e8ee8_row6_col3,#T_e8ee8_row6_col4,#T_e8ee8_row6_col5,#T_e8ee8_row7_col3,#T_e8ee8_row7_col4{
#             background-color:  #a6cee3;
#             color:  #000000;
#         }#T_e8ee8_row1_col0,#T_e8ee8_row1_col1,#T_e8ee8_row1_col2,#T_e8ee8_row5_col0,#T_e8ee8_row5_col1,#T_e8ee8_row5_col2{
# ...

# %% [markdown]
# ### Rotten Tomatoes
#
# Let's first take a look at Rotten Tomatoes. RT has two sets of reviews, their critics reviews (ratings published by official critics) and user reviews.
#
# **Creating a scatterplot exploring the relationship between RT Critic reviews and RT User reviews.**

# %%
sns.scatterplot(data=all_sites,x='RottenTomatoes',y='RottenTomatoes_User')
plt.xlim(0,100)
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# Let's quantify this difference by comparing the critics ratings and the RT User ratings. We will calculate this with RottenTomatoes-RottenTomatoes_User. Values closer to 0 means aggrement between Critics and Users. Larger positive values means critics rated much higher than users. Larger negative values means users rated much higher than critics.
#
# **Creating a new column based off the difference between critics ratings and users ratings for Rotten Tomatoes(Calculate this with RottenTomatoes-RottenTomatoes_User)**

# %%
all_sites['Rotten_Diff']  = all_sites['RottenTomatoes'] - all_sites['RottenTomatoes_User']

# %% [markdown]
# Let's now compare the overall mean difference. Since we're dealing with differences that could be negative or positive, firstly taking the absolute value of all the differences and then taking the mean. This would report back on average to absolute difference between the critics rating versus the user rating.

# %% [markdown]
# **Calculating the Mean Absolute Difference between RT scores and RT User scores as described above.**

# %%
all_sites['Rotten_Diff'].apply(abs).mean()
# Out:
# 15.095890410958905

# %% [markdown]
# **Plotting the distribution of the differences between RT Critics Score and RT User Score. There should be negative values in this distribution plot**

# %%
sns.histplot(data=all_sites,x='Rotten_Diff',kde=True,bins=25)
plt.title("RT Critics Score minus RT User Score");

# %% [markdown]
# **Now creating a distribution showing the *absolute value* difference between Critics and Users on Rotten Tomatoes.**

# %%
sns.histplot(x=all_sites['Rotten_Diff'].apply(abs),bins=25,kde=True)
plt.title("Abs Difference between RT Critics Score and RT User Score");

# %% [markdown]
# **Let's find out which movies are causing the largest differences. Firstliy, show the top 5 movies with the largest *negative* difference between Users and RT critics. Since we calculated the difference as Critics Rating - Users Rating, then large negative values imply the users rated the movie much higher on average than the critics did.**

# %% [markdown]
# **Top 5 movies users rated higher than critics on average:**

# %%
print("Users Love but Critics Hate")
all_sites.nsmallest(5,'Rotten_Diff')[['FILM','Rotten_Diff']]
# Out:
# Users Love but Critics Hate
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 105    Hitman: Agent 47 (2015)          -42
# 134    The Longest Ride (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %% [markdown]
# **Now showing the top 5 movies critics scores higher than users on average.**

# %%
print("Critics love, but Users Hate")
all_sites.nlargest(5,'Rotten_Diff')[['FILM','Rotten_Diff']]
# Out:
# Critics love, but Users Hate
#                                  FILM  Rotten_Diff
# 69                  Mr. Turner (2014)           42
# 112                 It Follows (2015)           31
# 115          While We're Young (2015)           31
# 37               Welcome to Me (2015)           24
# 40   I'll See You In My Dreams (2015)           24

# %% [markdown]
# ## MetaCritic
#
# Now let's take a quick look at the ratings from MetaCritic. Metacritic also shows an average user rating versus their official displayed rating.

# %% [markdown]
# **Displaying a scatterplot of the Metacritic Rating versus the Metacritic User rating.**

# %%
sns.scatterplot(data=all_sites,x='Metacritic',y='Metacritic_User')
plt.xlim(0,100)
plt.ylim(0,10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ### IMBD
#
# Finally let's explore IMDB.
#
# **Creating a scatterplot for the relationship between vote counts on MetaCritic versus vote counts on IMDB.**

# %%
sns.scatterplot(data=all_sites,x='Metacritic_user_vote_count',y='IMDB_user_vote_count')
# Out:
# <AxesSubplot:xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %% [markdown]
# **We can see that there are two outliers here. The movie with the highest vote count on IMDB only has about 500 Metacritic ratings. What is this movie?**
#
# **Movie that has the highest IMDB user vote count?**

# %%
all_sites.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %% [markdown]
# **Movie that has the highest Metacritic User Vote count?**

# %%
all_sites.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %% [markdown]
# ## Fandago Scores vs. All Sites
#
# Finally let's begin to explore whether or not Fandango artificially displays higher ratings than warranted to boost ticket sales.

# %% [markdown]
# **Combining the Fandango Table with the All Sites table. Not every movie in the Fandango table is in the All Sites table, since some Fandango movies have very little or no reviews. We only want to compare movies that are in both DataFrames, so do an *inner* merge to merge together both DataFrames based on the FILM columns.**

# %%
df = pd.merge(fandango,all_sites,on='FILM',how='inner')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  Rotten_Diff                 145 non-null    int64
# ...

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES   YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015)              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015)              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015)              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015)              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015)              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff
# 0                         778                179506          -17
# ...

# %% [markdown]
# ### Normalizing columns to Fandango STARS and RATINGS 0-5
#
# We can Notice that RT,Metacritic, and IMDB don't use a score between 0-5 stars like Fandango does. In order to do a fair comparison, we need to *normalize* these values so they all fall between 0-5 stars and the relationship between reviews stays the same.

# %%
df['RT_Norm'] = np.round(df['RottenTomatoes']/20,1)
df['RTU_Norm'] =  np.round(df['RottenTomatoes_User']/20,1)

# %%
df['Meta_Norm'] =  np.round(df['Metacritic']/20,1)
df['Meta_U_Norm'] =  np.round(df['Metacritic_User']/2,1)

# %%
df['IMDB_Norm'] = np.round(df['IMDB']/2,1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES   YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015)              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015)              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015)              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015)              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015)              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  RT_Norm  \
# 0                         778                179506          -17      1.2
# ...

# %% [markdown]
# **Now creating a norm_scores DataFrame that only contains the normalizes ratings. Including both STARS and RATING from the original Fandango table.**

# %%
norm_scores = df[['STARS','RATING','RT_Norm','RTU_Norm','Meta_Norm','Meta_U_Norm','IMDB_Norm']]

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0    4.0     3.9      1.2       2.1        2.3          1.6        2.1
# 1    4.5     4.5      3.6       4.0        3.0          3.5        3.6
# 2    5.0     4.8      3.6       4.2        3.6          3.3        3.7
# 3    5.0     4.8      4.0       4.2        3.4          3.4        3.7
# 4    4.5     4.5      4.9       4.5        4.7          4.4        4.3

# %% [markdown]
# ### Comparing Distribution of Scores Across Sites
#
#
# Now the moment of truth! Does Fandango display abnormally high ratings? We already know it pushs displayed RATING higher than STARS, but are the ratings themselves higher than average?
#
#
# **Creating a plot comparing the distributions of normalized ratings across all sites.**

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig, ax = plt.subplots(figsize=(15,6),dpi=150)
sns.kdeplot(data=norm_scores,clip=[0,5],shade=True,palette='Set1',ax=ax)
move_legend(ax, "upper left")

# %% [markdown]
# **Clearly Fandango has an uneven distribution. We can also see that RT critics have the most uniform distribution. Let's directly compare these two.**
#
# **Creating a KDE plot that compare the distribution of RT critic ratings against the STARS displayed by Fandango.**

# %%
fig, ax = plt.subplots(figsize=(15,6),dpi=150)
sns.kdeplot(data=norm_scores[['RT_Norm','STARS']],clip=[0,5],shade=True,palette='Set1',ax=ax)
move_legend(ax, "upper left")

# %% [markdown]
# **Creating a histplot comparing all normalized scores.**

# %%
plt.subplots(figsize=(15,6),dpi=150)
sns.histplot(norm_scores,bins=50)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### How are the worst movies rated across all platforms?
#
# **Creating a clustermap visualization of all normalized scores**

# %%
sns.clustermap(norm_scores,cmap='magma',col_cluster=False)

# %% [markdown]
# **Clearly Fandango is rating movies much higher than other sites, especially considering that it is then displaying a rounded up version of the rating. Let's examine the top 10 worst movies. Based off the Rotten Tomatoes Critic Ratings, let's see what are the top 10 lowest rated movies? What are the normalized scores across all platforms for these movies?**

# %%
norm_films = df[['STARS','RATING','RT_Norm','RTU_Norm','Meta_Norm','Meta_U_Norm','IMDB_Norm','FILM']]

# %%
norm_films.nsmallest(10,'RT_Norm')
# Out:
#     STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 49    3.5     3.5      0.2       1.8        0.6          1.2        2.2
# 25    4.5     4.1      0.4       2.3        1.3          2.3        3.0
# 28    3.0     2.7      0.4       1.0        1.4          1.2        2.0
# 54    4.0     3.7      0.4       1.8        1.6          1.8        2.4
# 84    4.0     3.9      0.4       2.4        1.4          1.6        3.0
# 50    4.0     3.6      0.5       1.8        1.5          2.8        2.3
# 77    3.5     3.2      0.6       1.8        1.5          2.0        2.8
# 78    3.5     3.2      0.6       1.5        1.4          1.6        2.8
# 83    3.5     3.3      0.6       1.7        1.6          2.5        2.8
# 87    3.5     3.2      0.6       1.4        1.6          1.9        2.7
#
#                              FILM
# 49  Paul Blart: Mall Cop 2 (2015)
# 25                 Taken 3 (2015)
# 28          Fantastic Four (2015)
# 54             Hot Pursuit (2015)
# ...

# %% [markdown]
# **Finally let's Visualize the distribution of ratings across all sites for the top 10 worst movies.**

# %%
print('\n\n')
plt.figure(figsize=(15,6),dpi=150)
worst_films = norm_films.nsmallest(10,'RT_Norm').drop('FILM',axis=1)
sns.kdeplot(data=worst_films,clip=[0,5],shade=True,palette='Set1')
plt.title("Ratings for RT Critic's 10 Worst Reviewed Films");

# %% [markdown]
# ---
# ----
#
# <img src="https://upload.wikimedia.org/wikipedia/en/6/6f/Taken_3_poster.jpg">
#
# **Final thoughts: Wow! Fandango is showing around 3-4 star ratings for films that are clearly bad! Also Notice the biggest offender, [Taken 3!](https://www.youtube.com/watch?v=tJrfImRCHJ0). Fandango is displaying 4.5 stars on their site for a film with an [average rating of 1.86](https://en.wikipedia.org/wiki/Taken_3#Critical_response) across the other platforms!**

# %%
norm_films.iloc[25]
# Out:
# STARS                     4.5
# RATING                    4.1
# RT_Norm                   0.4
# RTU_Norm                  2.3
# Meta_Norm                 1.3
# Meta_U_Norm               2.3
# IMDB_Norm                 3.0
# FILM           Taken 3 (2015)
# Name: 25, dtype: object

# %%
0.4+2.3+1.3+2.3+3
# Out:
# 9.3

# %%
9.3/5
# Out:
# 1.86

# %% [markdown]
# ----
